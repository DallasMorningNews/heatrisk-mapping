# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/asaldanha'

# %%
os.chdir('/Users/asaldanha/Work/python')

# %%
os.getcwd()
# Out:
# '/Users/asaldanha/Work/python'

# %%
import pandas as pd

# %%
hdf = pd.read_csv("/Users/asaldanha/Downloads/hhi_tx.csv")

# %%
dataTypeSeries = hdf.dtypes
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# STATEFP10          int64
# STATE             object
# STATE_ABV         object
# ZCTA               int64
# GEOID10            int64
#                   ...
# PR_PM25          float64
# NBE_SCORE        float64
# NBE_RANK         float64
# OVERALL_SCORE    float64
# OVERALL_RANK     float64
# Length: 75, dtype: object

# %%
hdf['GEOID10'] = hdf['GEOID10'].astype(str).apply(lambda x: x.replace('.0',''))

# %%
hdf['ZCTA'] = hdf['ZCTA'].astype(str).apply(lambda x: x.replace('.0',''))

# %%
dataTypeSeries = hdf.dtypes
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# STATEFP10          int64
# STATE             object
# STATE_ABV         object
# ZCTA              object
# GEOID10           object
#                   ...
# PR_PM25          float64
# NBE_SCORE        float64
# NBE_RANK         float64
# OVERALL_SCORE    float64
# OVERALL_RANK     float64
# Length: 75, dtype: object

# %%
hdf.head()
# Out:
#    STATEFP10 STATE STATE_ABV   ZCTA  GEOID10  MULTI_STATE    POP  PR_HRI  \
# 0         48    TX     Texas  73949  4873949            1   1688      68
# 1         48    TX     Texas  75001  4875001            0  12414      78
# 2         48    TX     Texas  75002  4875002            0  63140      54
# 3         48    TX     Texas  75006  4875006            0  46364      70
# 4         48    TX     Texas  75007  4875007            0  51624      65
#
#    F_HRI  LOW_EMS  ...     P_RENT  PR_RENT   P_OZONE  PR_OZONE    P_PM25  \
# 0   0.75        0  ...  34.928230   0.7684  0.666667    0.6180  0.000000
# 1   1.00        0  ...  82.888424   0.9852  5.333333    0.9472  1.333333
# 2   0.75        0  ...  21.299188   0.4391  4.666667    0.9349  1.333333
# 3   0.75        0  ...  49.364908   0.9031  6.000000    0.9573  1.333333
# 4   0.75        0  ...  27.721552   0.6238  6.000000    0.9573  1.333333
#
#    PR_PM25  NBE_SCORE  NBE_RANK  OVERALL_SCORE  OVERALL_RANK
# ...

# %%
num_vars = hdf.columns[hdf.dtypes != 'object']
print(num_vars)
# Out:
# Index(['STATEFP10', 'MULTI_STATE', 'POP', 'PR_HRI', 'F_HRI', 'LOW_EMS',
#        'P_NEHD', 'PR_NEHD', 'HHB_SCORE', 'HHB_RANK', 'P_CHD', 'PR_CHD',
#        'F_CHD', 'P_OBS', 'PR_OBS', 'F_OBS', 'P_DIABETES', 'PR_DIABETES',
#        'F_DIABETES', 'P_COPD', 'PR_COPD', 'F_COPD', 'P_ASTHMA', 'PR_ASTHMA',
#        'F_ASTHMA', 'P_MNTHL', 'PR_MNTHL', 'F_MNTHL', 'F_SEN_COUNT',
#        'SEN_SCORE', 'SEN_RANK', 'P_UNINSUR', 'PR_UNINSUR', 'P_POV', 'PR_POV',
#        'P_UNEMP', 'PR_UNEMP', 'P_NOHSDP', 'PR_NOHSDP', 'P_ISO', 'PR_ISO',
#        'P_ELP', 'PR_ELP', 'P_DISABL', 'PR_DISABL', 'P_ODW', 'PR_ODW',
#        'P_AGE65', 'PR_AGE65', 'P_AGE5', 'PR_AGE5', 'SOCIODEM_SCORE',
#        'SOCIODEM_RANK', 'P_IMPERV', 'PR_IMPERV', 'P_TREEC', 'PR_TREEC',
#        'P_NOVEH', 'PR_NOVEH', 'P_MOBILE', 'PR_MOBILE', 'P_RENT', 'PR_RENT',
#        'P_OZONE', 'PR_OZONE', 'P_PM25', 'PR_PM25', 'NBE_SCORE', 'NBE_RANK',
#        'OVERALL_SCORE', 'OVERALL_RANK'],
#       dtype='object')

# %%
char_vars = hdf.columns[hdf.dtypes == 'object']
print(char_vars)
# Out:
# Index(['STATE', 'STATE_ABV', 'ZCTA', 'GEOID10'], dtype='object')

# %%
import geopandas as gpd

# %%
zipshp = gpd.read_file('/Users/asaldanha/Downloads/tl_2020_us_zcta520/tl_2020_us_zcta520.shp')

# %%
zipshp.head()
# Out:
#   ZCTA5CE20 GEOID20 CLASSFP20 MTFCC20 FUNCSTAT20    ALAND20  AWATER20  \
# 0     35592   35592        B5   G6350          S  298552385    235989
# 1     35616   35616        B5   G6350          S  559506992  41870756
# 2     35621   35621        B5   G6350          S  117838488    409438
# 3     35651   35651        B5   G6350          S  104521045    574316
# 4     36010   36010        B5   G6350          S  335675180    236811
#
#     INTPTLAT20    INTPTLON20  \
# 0  +33.7427261  -088.0973903
# 1  +34.7395036  -088.0193814
# 2  +34.3350314  -086.7270557
# 3  +34.4609087  -087.4801507
# 4  +31.6598950  -085.8128958
#
#                                             geometry
# 0  POLYGON ((-88.24735 33.6539, -88.24713 33.6541...
# 1  POLYGON ((-88.13997 34.58184, -88.13995 34.582...
# 2  POLYGON ((-86.81659 34.3496, -86.81648 34.3496...
# 3  POLYGON ((-87.53087 34.42492, -87.53082 34.429...
# 4  POLYGON ((-85.95712 31.67744, -85.95676 31.677...

# %%
counties = gpd.read_file('/Users/asaldanha/Downloads/tl_2019_us_county/tl_2019_us_county.shp')

# %%
print(counties.columns.tolist())
# Out:
# ['STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD', 'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry']

# %%
print(counties['COUNTYFP'])
# Out:
# 0       039
# 1       069
# 2       011
# 3       109
# 4       129
#        ...
# 3228    123
# 3229    135
# 3230    089
# 3231    227
# 3232    099
# Name: COUNTYFP, Length: 3233, dtype: object

# %%
dallas = counties[counties['COUNTYFP']=='113']

# %%
print(dallas)
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID        NAME           NAMELSAD LSAD  \
# 125       05      113  00069175  05113        Polk        Polk County   06
# 148       17      113  01784833  17113      McLean      McLean County   06
# 404       20      113  00485021  20113   McPherson   McPherson County   06
# 637       08      113  00198172  08113  San Miguel  San Miguel County   06
# 759       13      113  01687740  13113     Fayette     Fayette County   06
# 780       22      113  00559538  22113   Vermilion   Vermilion Parish   15
# 864       36      113  00974154  36113      Warren      Warren County   06
# 865       51      113  01494590  51113     Madison     Madison County   06
# 953       19      113  00465245  19113        Linn        Linn County   06
# 1165      42      113  01213687  42113    Sullivan    Sullivan County   06
# 1205      72      113  01804537  72113       Ponce    Ponce Municipio   13
# ...

# %%
dataTypeSeries = counties.dtypes
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# STATEFP       object
# COUNTYFP      object
# COUNTYNS      object
# GEOID         object
# NAME          object
# NAMELSAD      object
# LSAD          object
# CLASSFP       object
# MTFCC         object
# CSAFP         object
# CBSAFP        object
# METDIVFP      object
# FUNCSTAT      object
# ALAND          int64
# AWATER         int64
# INTPTLAT      object
# INTPTLON      object
# geometry    geometry
# dtype: object

# %%
dallas.to_file('/Users/asaldanha/Work/python/data_created/dallas.geojson', driver='GeoJSON')

# %%
# https://geopandas.org/en/stable/docs/reference/api/geopandas.sjoin.html
# https://stackoverflow.com/questions/68504942/how-do-geopandas-sjoin-predicate-within-and-intersects-differ

# %%
dallas_zipcodes = gpd.sjoin(zipcodes, dallas, how='inner', predicate='intersects')

# %%
dallas_zipcodes.to_file('/Users/asaldanha/Work/python/data_created/dallas_zipcodes.geojson', driver='GeoJSON')

# %%
dallas_zipcodes.head()
# Out:
#     ZCTA5CE20 GEOID20 CLASSFP20 MTFCC20 FUNCSTAT20    ALAND20  AWATER20  \
# 107     32514   32514        B5   G6350          S   51328342   1128346
# 108     32564   32564        B5   G6350          S  266662769   2894289
# 175     32565   32565        B5   G6350          S  596655238   6159122
# 196     32566   32566        B5   G6350          S  101447890  33312858
# 235     32563   32563        B5   G6350          S   43086275  25929046
#
#       INTPTLAT20    INTPTLON20  \
# 107  +30.5321804  -087.2225390
# 108  +30.7288078  -086.7819153
# 175  +30.8943800  -087.1454537
# 196  +30.4253015  -086.8923457
# 235  +30.3908515  -087.0247850
#
#                                               geometry  ...  CLASSFP  MTFCC  \
# 107  POLYGON ((-87.26444 30.53708, -87.26395 30.537...  ...       H1  G4020
# 108  POLYGON ((-86.9071 30.69625, -86.90697 30.6962...  ...       H1  G4020
# 175  POLYGON ((-87.31391 30.84871, -87.31358 30.849...  ...       H1  G4020
# ...

# %%
print(dallas_zipcodes)
# Out:
#       ZCTA5CE20 GEOID20 CLASSFP20 MTFCC20 FUNCSTAT20    ALAND20  AWATER20  \
# 107       32514   32514        B5   G6350          S   51328342   1128346
# 108       32564   32564        B5   G6350          S  266662769   2894289
# 175       32565   32565        B5   G6350          S  596655238   6159122
# 196       32566   32566        B5   G6350          S  101447890  33312858
# 235       32563   32563        B5   G6350          S   43086275  25929046
# ...         ...     ...       ...     ...        ...        ...       ...
# 33224     67476   67476        B5   G6350          S    7845986      4790
# 33301     46796   46796        B5   G6350          S      71234         0
# 33722     22725   22725        B5   G6350          S    1876696      4634
# 33740     75261   75261        B5   G6350          S   36083571    178186
# 33779     12820   12820        B5   G6350          S     331799         0
#
#         INTPTLAT20    INTPTLON20  \
# 107    +30.5321804  -087.2225390
# ...

# %%
print(hdf)
# Out:
#       STATEFP10 STATE STATE_ABV   ZCTA  GEOID10  MULTI_STATE     POP  PR_HRI  \
# 0            48    TX     Texas  73949  4873949            1    1688      68
# 1            48    TX     Texas  75001  4875001            0   12414      78
# 2            48    TX     Texas  75002  4875002            0   63140      54
# 3            48    TX     Texas  75006  4875006            0   46364      70
# 4            48    TX     Texas  75007  4875007            0   51624      65
# ...         ...   ...       ...    ...      ...          ...     ...     ...
# 1895         48    TX     Texas  79936  4879936            0  111086      45
# 1896         48    TX     Texas  79938  4879938            0   53520      42
# 1897         48    TX     Texas  88063  4888063            1   12799      78
# 1898         48    TX     Texas  88220  4888220            1   33725    -999
# 1899         48    TX     Texas  88430  4888430            1     162      20
#
# ...

# %%
pepefile = gpd.read_file('/Users/asaldanha/Downloads/Northtexas-zipcodes (2).geojson')

# %%
pepefile.head()
# Out:
#    STATEFP  COUNTYFP  COUNTYNS  GEOID         GEOIDFQ    NAME       NAMELSAD  \
# 0       48       147   1383859  48147  0500000US48147  Fannin  Fannin County
# 1       48       147   1383859  48147  0500000US48147  Fannin  Fannin County
# 2       48       147   1383859  48147  0500000US48147  Fannin  Fannin County
# 3       48       147   1383859  48147  0500000US48147  Fannin  Fannin County
# 4       48       147   1383859  48147  0500000US48147  Fannin  Fannin County
#
#    LSAD CLASSFP  MTFCC  ...  ZCTA5CE10  GEOID10 CLASSFP10 MTFCC10  FUNCSTAT10  \
# 0     6      H1  G4020  ...      75098    75098        B5   G6350           S
# 1     6      H1  G4020  ...      75101    75101        B5   G6350           S
# 2     6      H1  G4020  ...      75103    75103        B5   G6350           S
# 3     6      H1  G4020  ...      75104    75104        B5   G6350           S
# 4     6      H1  G4020  ...      75105    75105        B5   G6350           S
#
# ...

# %%
hdf.head()
# Out:
#    STATEFP10 STATE STATE_ABV   ZCTA  GEOID10  MULTI_STATE    POP  PR_HRI  \
# 0         48    TX     Texas  73949  4873949            1   1688      68
# 1         48    TX     Texas  75001  4875001            0  12414      78
# 2         48    TX     Texas  75002  4875002            0  63140      54
# 3         48    TX     Texas  75006  4875006            0  46364      70
# 4         48    TX     Texas  75007  4875007            0  51624      65
#
#    F_HRI  LOW_EMS  ...     P_RENT  PR_RENT   P_OZONE  PR_OZONE    P_PM25  \
# 0   0.75        0  ...  34.928230   0.7684  0.666667    0.6180  0.000000
# 1   1.00        0  ...  82.888424   0.9852  5.333333    0.9472  1.333333
# 2   0.75        0  ...  21.299188   0.4391  4.666667    0.9349  1.333333
# 3   0.75        0  ...  49.364908   0.9031  6.000000    0.9573  1.333333
# 4   0.75        0  ...  27.721552   0.6238  6.000000    0.9573  1.333333
#
#    PR_PM25  NBE_SCORE  NBE_RANK  OVERALL_SCORE  OVERALL_RANK
# ...

# %%
hdf.rename(columns={'ZCTA':'ZCTA5CE10'}, inplace=True)

# %%
hdf.head()
# Out:
#    STATEFP10 STATE STATE_ABV ZCTA5CE10  GEOID10  MULTI_STATE    POP  PR_HRI  \
# 0         48    TX     Texas     73949  4873949            1   1688      68
# 1         48    TX     Texas     75001  4875001            0  12414      78
# 2         48    TX     Texas     75002  4875002            0  63140      54
# 3         48    TX     Texas     75006  4875006            0  46364      70
# 4         48    TX     Texas     75007  4875007            0  51624      65
#
#    F_HRI  LOW_EMS  ...     P_RENT  PR_RENT   P_OZONE  PR_OZONE    P_PM25  \
# 0   0.75        0  ...  34.928230   0.7684  0.666667    0.6180  0.000000
# 1   1.00        0  ...  82.888424   0.9852  5.333333    0.9472  1.333333
# 2   0.75        0  ...  21.299188   0.4391  4.666667    0.9349  1.333333
# 3   0.75        0  ...  49.364908   0.9031  6.000000    0.9573  1.333333
# 4   0.75        0  ...  27.721552   0.6238  6.000000    0.9573  1.333333
#
#    PR_PM25  NBE_SCORE  NBE_RANK  OVERALL_SCORE  OVERALL_RANK
# ...

# %%
dataTypeSeries = hdf.dtypes
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# STATEFP10          int64
# STATE             object
# STATE_ABV         object
# ZCTA5CE10         object
# GEOID10           object
#                   ...
# PR_PM25          float64
# NBE_SCORE        float64
# NBE_RANK         float64
# OVERALL_SCORE    float64
# OVERALL_RANK     float64
# Length: 75, dtype: object

# %%
dataTypeSeries = pepefile.dtypes
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# STATEFP          int32
# COUNTYFP         int32
# COUNTYNS         int32
# GEOID            int32
# GEOIDFQ         object
# NAME            object
# NAMELSAD        object
# LSAD             int32
# CLASSFP         object
# MTFCC           object
# CSAFP            int32
# CBSAFP           int32
# METDIVFP        object
# FUNCSTAT        object
# ALAND            int64
# AWATER           int32
# INTPTLAT       float64
# INTPTLON       float64
# ZCTA5CE10        int32
# GEOID10          int32
# CLASSFP10       object
# MTFCC10         object
# FUNCSTAT10      object
# ALAND10          int32
# AWATER10         int32
# INTPTLAT10     float64
# INTPTLON10     float64
# geometry      geometry
# dtype: object

# %%
pepefile['ZCTA5CE10'] = pepefile['ZCTA5CE10'].astype(str).apply(lambda x: x.replace('.0',''))

# %%
dataTypeSeries = pepefile.dtypes
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# STATEFP          int32
# COUNTYFP         int32
# COUNTYNS         int32
# GEOID            int32
# GEOIDFQ         object
# NAME            object
# NAMELSAD        object
# LSAD             int32
# CLASSFP         object
# MTFCC           object
# CSAFP            int32
# CBSAFP           int32
# METDIVFP        object
# FUNCSTAT        object
# ALAND            int64
# AWATER           int32
# INTPTLAT       float64
# INTPTLON       float64
# ZCTA5CE10       object
# GEOID10          int32
# CLASSFP10       object
# MTFCC10         object
# FUNCSTAT10      object
# ALAND10          int32
# AWATER10         int32
# INTPTLAT10     float64
# INTPTLON10     float64
# geometry      geometry
# dtype: object

# %%
#merge data with geojson file to get north texas data and mapping

# %%
dallas_heatzips = gpd.GeoDataFrame(hdf.merge(pepefile, on="ZCTA5CE10"))

# %%
print(dallas_heatzips)
# Out:
#      STATEFP10 STATE STATE_ABV ZCTA5CE10 GEOID10_x  MULTI_STATE    POP  \
# 0           48    TX     Texas     75001   4875001            0  12414
# 1           48    TX     Texas     75002   4875002            0  63140
# 2           48    TX     Texas     75006   4875006            0  46364
# 3           48    TX     Texas     75007   4875007            0  51624
# 4           48    TX     Texas     75009   4875009            0   8785
# ..         ...   ...       ...       ...       ...          ...    ...
# 322         48    TX     Texas     76623   4876623            0    242
# 323         48    TX     Texas     76651   4876651            0   3300
# 324         48    TX     Texas     76652   4876652            0   1087
# 325         48    TX     Texas     76666   4876666            0    244
# 326         48    TX     Texas     76670   4876670            0   1377
#
#      PR_HRI  F_HRI  LOW_EMS  ...   INTPTLON  GEOID10_y  CLASSFP10  MTFCC10  \
# ...

# %%
print(pepefile)
# Out:
#      STATEFP  COUNTYFP  COUNTYNS  GEOID         GEOIDFQ    NAME  \
# 0         48       147   1383859  48147  0500000US48147  Fannin
# 1         48       147   1383859  48147  0500000US48147  Fannin
# 2         48       147   1383859  48147  0500000US48147  Fannin
# 3         48       147   1383859  48147  0500000US48147  Fannin
# 4         48       147   1383859  48147  0500000US48147  Fannin
# ..       ...       ...       ...    ...             ...     ...
# 337       48       147   1383859  48147  0500000US48147  Fannin
# 338       48       147   1383859  48147  0500000US48147  Fannin
# 339       48       147   1383859  48147  0500000US48147  Fannin
# 340       48       147   1383859  48147  0500000US48147  Fannin
# 341       48       147   1383859  48147  0500000US48147  Fannin
#
#           NAMELSAD  LSAD CLASSFP  MTFCC  ...  ZCTA5CE10  GEOID10 CLASSFP10  \
# 0    Fannin County     6      H1  G4020  ...      75098    75098        B5
# ...

# %%
dallas_heatzips.to_file('/Users/asaldanha/Work/python/data_created/dallas_heatzips.geojson', driver='GeoJSON')

# %%
#narrow down to dallas region with help from NCTOG open map files

# %%
dallas_city = gpd.read_file('/Users/asaldanha/Downloads/Cities_Region_(2024).geojson')

# %%
dallas_city.head()
# Out:
#    OBJECTID           CITY  TYPE FIPSCODE    GEOID        NOTES UPDATE_YEAR  \
# 0         1          Aledo  City    01744  4801744          PDF        2021
# 1         2         Alvord  Town    02284  4802284  Geodatabase        2024
# 2         3          Angus  City    03288  4803288  Geodatabase        2024
# 3         4  Annetta North  Town    03340  4803340          PDF        2019
# 4         5  Annetta South  Town    03342  4803342          JPG        2018
#
#              SOURCE  AREA_SQ_MI FIPSCODE_OLD  ShapeSTLength   ShapeSTArea  \
# 0              City    2.656081        01744   63456.619093  7.404729e+07
# 1     NCT9-1-1 Wise    1.536303        02284   51643.470741  4.282966e+07
# 2  NCT9-1-1 Navarro    3.132794        03288  131282.566357  8.733728e+07
# 3              City    4.623113        03340  112418.007043  1.288850e+08
# 4              City    1.775799        03342   84788.349771  4.950644e+07
#
#                                             geometry
# ...

# %%
layer_dallas =  dallas_city[(dallas_city.CITY == "Dallas")]

# %%
layer_dallas.head()
# Out:
#      OBJECTID    CITY  TYPE FIPSCODE    GEOID      NOTES UPDATE_YEAR SOURCE  \
# 165       166  Dallas  City    19000  4819000  Shapefile        2024   City
#
#      AREA_SQ_MI FIPSCODE_OLD  ShapeSTLength   ShapeSTArea  \
# 165   383.93871        19000   1.718854e+06  1.070360e+10
#
#                                               geometry
# 165  POLYGON ((-96.47076 33.02013, -96.47168 33.020...

# %%
print(layer_dallas)
# Out:
# Empty GeoDataFrame
# Columns: [OBJECTID, CITY, TYPE, FIPSCODE, GEOID, NOTES, UPDATE_YEAR, SOURCE, AREA_SQ_MI, FIPSCODE_OLD, ShapeSTLength, ShapeSTArea, geometry]
# Index: []

# %%
dallas_heatzips.head()
# Out:
#    STATEFP10 STATE STATE_ABV ZCTA5CE10 GEOID10_x  MULTI_STATE    POP  PR_HRI  \
# 0         48    TX     Texas     75001   4875001            0  12414      78
# 1         48    TX     Texas     75002   4875002            0  63140      54
# 2         48    TX     Texas     75006   4875006            0  46364      70
# 3         48    TX     Texas     75007   4875007            0  51624      65
# 4         48    TX     Texas     75009   4875009            0   8785      87
#
#    F_HRI  LOW_EMS  ...   INTPTLON  GEOID10_y  CLASSFP10  MTFCC10  FUNCSTAT10  \
# 0   1.00        0  ... -96.104988      75001         B5    G6350           S
# 1   0.75        0  ... -96.104988      75002         B5    G6350           S
# 2   0.75        0  ... -96.104988      75006         B5    G6350           S
# 3   0.75        0  ... -96.104988      75007         B5    G6350           S
# 4   1.00        0  ... -96.104988      75009         B5    G6350           S
#
# ...

# %%
dallas_city_hdf = gpd.sjoin(dallas_heatzips, layer_dallas, how='inner', predicate='intersects')

# %%
print(dallas_city_hdf)
# Out:
#      STATEFP10 STATE STATE_ABV ZCTA5CE10 GEOID10_x  MULTI_STATE    POP  \
# 0           48    TX     Texas     75001   4875001            0  12414
# 2           48    TX     Texas     75006   4875006            0  46364
# 3           48    TX     Texas     75007   4875007            0  51624
# 7           48    TX     Texas     75019   4875019            0  38666
# 15          48    TX     Texas     75032   4875032            0  27986
# ..         ...   ...       ...       ...       ...          ...    ...
# 144         48    TX     Texas     75251   4875251            0   2331
# 145         48    TX     Texas     75252   4875252            0  24112
# 146         48    TX     Texas     75253   4875253            0  18450
# 147         48    TX     Texas     75254   4875254            0  23253
# 148         48    TX     Texas     75287   4875287            0  49004
#
#      PR_HRI  F_HRI  LOW_EMS  ...  TYPE  FIPSCODE  GEOID_right      NOTES  \
# ...

# %%
dallas_city_hdf.to_file('/Users/asaldanha/Work/python/data_created/dallas_cityheat.geojson', driver='GeoJSON')

# %%
dallas_city_hdf.head()
# Out:
#     STATEFP10 STATE STATE_ABV ZCTA5CE10 GEOID10_x  MULTI_STATE    POP  PR_HRI  \
# 0          48    TX     Texas     75001   4875001            0  12414      78
# 2          48    TX     Texas     75006   4875006            0  46364      70
# 3          48    TX     Texas     75007   4875007            0  51624      65
# 7          48    TX     Texas     75019   4875019            0  38666      79
# 15         48    TX     Texas     75032   4875032            0  27986      75
#
#     F_HRI  LOW_EMS  ...  TYPE  FIPSCODE  GEOID_right      NOTES  UPDATE_YEAR  \
# 0    1.00        0  ...  City     19000      4819000  Shapefile         2024
# 2    0.75        0  ...  City     19000      4819000  Shapefile         2024
# 3    0.75        0  ...  City     19000      4819000  Shapefile         2024
# 7    1.00        0  ...  City     19000      4819000  Shapefile         2024
# 15   1.00        0  ...  City     19000      4819000  Shapefile         2024
#
# ...

# %%
gdf = dallas_city_hdf

# %%
print(gdf)
# Out:
#     STATE_ABV ZCTA5CE10 GEOID10_x    POP  PR_HRI  F_HRI  LOW_EMS      P_NEHD  \
# 0       Texas     75001   4875001  12414      78   1.00        0   14.200000
# 2       Texas     75006   4875006  46364      70   0.75        0   14.266667
# 3       Texas     75007   4875007  51624      65   0.75        0   14.255556
# 7       Texas     75019   4875019  38666      79   1.00        0   14.400000
# 15      Texas     75032   4875032  27986      75   1.00        0   15.800000
# ..        ...       ...       ...    ...     ...    ...      ...         ...
# 144     Texas     75251   4875251   2331      92   1.00        0 -999.000000
# 145     Texas     75252   4875252  24112      48   0.50        0   14.220000
# 146     Texas     75253   4875253  18450      56   0.75        0   14.933333
# 147     Texas     75254   4875254  23253      56   0.75        0   14.200000
# 148     Texas     75287   4875287  49004      55   0.75        0   14.200000
#
# ...

# %%
gdf.head()
# Out:
#    STATE_ABV ZCTA5CE10 GEOID10_x    POP  PR_HRI  F_HRI  LOW_EMS     P_NEHD  \
# 0      Texas     75001   4875001  12414      78   1.00        0  14.200000
# 2      Texas     75006   4875006  46364      70   0.75        0  14.266667
# 3      Texas     75007   4875007  51624      65   0.75        0  14.255556
# 7      Texas     75019   4875019  38666      79   1.00        0  14.400000
# 15     Texas     75032   4875032  27986      75   1.00        0  15.800000
#
#     PR_NEHD  HHB_SCORE  ...  INTPTLAT10  INTPTLON10  \
# 0    0.5885     0.7942  ...   32.960047  -96.838522
# 2    0.5989     0.6744  ...   32.962141  -96.898585
# 3    0.5987     0.6744  ...   33.005262  -96.896742
# 7    0.6046     0.8023  ...   32.963417  -96.984664
# 15   0.7305     0.8653  ...   32.857112  -96.431210
#
#                                              geometry  index_right  OBJECTID  \
# 0   MULTIPOLYGON (((-96.85888 32.95438, -96.85884 ...          165       166
# ...

# %%
gdf.drop(['INTPTLAT10', 'INTPTLON10', 
                'geometry', 'index_right', 'OBJECTID', 'CITY', 'TYPE', 'ShapeSTArea'], axis=1, inplace=True)

# %%
gdf.head()
# Out:
#    STATE_ABV ZCTA5CE10 GEOID10_x    POP  PR_HRI  F_HRI  LOW_EMS     P_NEHD  \
# 0      Texas     75001   4875001  12414      78   1.00        0  14.200000
# 2      Texas     75006   4875006  46364      70   0.75        0  14.266667
# 3      Texas     75007   4875007  51624      65   0.75        0  14.255556
# 7      Texas     75019   4875019  38666      79   1.00        0  14.400000
# 15     Texas     75032   4875032  27986      75   1.00        0  15.800000
#
#     PR_NEHD  HHB_SCORE  ...       NAMELSAD  LSAD  CLASSFP  MTFCC  CSAFP  \
# 0    0.5885     0.7942  ...  Fannin County     6       H1  G4020    206
# 2    0.5989     0.6744  ...  Fannin County     6       H1  G4020    206
# 3    0.5987     0.6744  ...  Fannin County     6       H1  G4020    206
# 7    0.6046     0.8023  ...  Fannin County     6       H1  G4020    206
# 15   0.7305     0.8653  ...  Fannin County     6       H1  G4020    206
#
#     CBSAFP  METDIVFP  FUNCSTAT       ALAND    AWATER
# ...

# %%
gdf.drop(['NAMELSAD', 'MTFCC', 'CLASSFP', 'LSAD', 'CSAFP', 'METDIVFP', 'FUNCSTAT', 'CBSAFP',
                'ALAND', 'AWATER'], axis=1, inplace=True)

# %%
print(gdf)
# Out:
#     STATE_ABV ZCTA5CE10 GEOID10_x    POP  PR_HRI  F_HRI  LOW_EMS      P_NEHD  \
# 0       Texas     75001   4875001  12414      78   1.00        0   14.200000
# 2       Texas     75006   4875006  46364      70   0.75        0   14.266667
# 3       Texas     75007   4875007  51624      65   0.75        0   14.255556
# 7       Texas     75019   4875019  38666      79   1.00        0   14.400000
# 15      Texas     75032   4875032  27986      75   1.00        0   15.800000
# ..        ...       ...       ...    ...     ...    ...      ...         ...
# 144     Texas     75251   4875251   2331      92   1.00        0 -999.000000
# 145     Texas     75252   4875252  24112      48   0.50        0   14.220000
# 146     Texas     75253   4875253  18450      56   0.75        0   14.933333
# 147     Texas     75254   4875254  23253      56   0.75        0   14.200000
# 148     Texas     75287   4875287  49004      55   0.75        0   14.200000
#
# ...

# %%
gdf.drop(['STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID_left', 'GEOIDFQ', 'NAME'], axis=1, inplace=True)

# %%
gdf.head()
# Out:
#    STATE_ABV ZCTA5CE10 GEOID10_x    POP  PR_HRI  F_HRI  LOW_EMS     P_NEHD  \
# 0      Texas     75001   4875001  12414      78   1.00        0  14.200000
# 2      Texas     75006   4875006  46364      70   0.75        0  14.266667
# 3      Texas     75007   4875007  51624      65   0.75        0  14.255556
# 7      Texas     75019   4875019  38666      79   1.00        0  14.400000
# 15     Texas     75032   4875032  27986      75   1.00        0  15.800000
#
#     PR_NEHD  HHB_SCORE  ...     P_RENT  PR_RENT   P_OZONE  PR_OZONE    P_PM25  \
# 0    0.5885     0.7942  ...  82.888424   0.9852  5.333333    0.9472  1.333333
# 2    0.5989     0.6744  ...  49.364908   0.9031  6.000000    0.9573  1.333333
# 3    0.5987     0.6744  ...  27.721552   0.6238  6.000000    0.9573  1.333333
# 7    0.6046     0.8023  ...  30.921540   0.6973  6.000000    0.9573  1.333333
# 15   0.7305     0.8653  ...  17.692646   0.3248  3.666667    0.9067  1.333333
#
# ...

# %%
gdf.to_csv('dallas_analysis.csv')
